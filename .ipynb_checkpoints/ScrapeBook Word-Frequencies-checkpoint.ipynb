# %% [markdown]
# # 1 Corpus beschaffen importieren

# %%
TafsirId = 2
Sura = 1
Aya = 6

# %%
import create_record as cr
import pandas as pd

corpus = pd.Series({}, dtype="object")

# %%
temp = cr.altafsir_extractor(TafsirId, Sura, Aya)
temp.collect_data()
corpus["Text"] = temp.Text
temp.write_data()
# Out:
# Writing to 2_1_6.txt
# Saved file successfully

# %% [markdown]
# # 2 Preprocessing
# ## 2.1 Normalizing data

# %%
from camel_tools.utils.normalize import normalize_unicode
from camel_tools.utils.dediac import dediac_ar


def reduce_to_archarset(text):
    import re
    # Remove non-arabic characters
    nonarab_chars = '[^\u0621-\u064A ]'
    text = re.sub(nonarab_chars, ' ', text)
    return text

def remove_aya(text):
    import re
    # Remove cited aya content
    aya = '\{(.*?)\}'
    text = re.sub(aya, '', text)
    return text

def remove_ref(text):
    import re
    # Remove reference to other ayas
    ref = '\[(.*?)\]'
    text = re.sub(ref, '', text)
    return text

def remove_eulogies(text):
    import re
    with open("./assets/eulogies.txt", encoding="utf-8") as f:
        eulogies = f.read().splitlines()
    for eulogy in eulogies:
        text = re.sub(eulogy, '', text)
    return text


## normalize
def normalizer(string):
    string_normalized = normalize_unicode(string)
    
    # remove diacritica
    string_normalized = dediac_ar(string_normalized)

    string_normalized = remove_ref(string_normalized)
    string_normalized = remove_aya(string_normalized)
    string_normalized = remove_eulogies(string_normalized)
    
    #reduce to arabic charset
    string_normalized = reduce_to_archarset(string_normalized)
    return string_normalized


corpus["TextNormalized"] = normalizer(corpus["Text"])

# %% [markdown]
# ## 2.2 Tokenization

# %%
from camel_tools.tokenizers.word import simple_word_tokenize

corpus["Tokenized"] = simple_word_tokenize(corpus["TextNormalized"])

# %% [markdown]
# ## 2.3 Disambiguation

# %%
from camel_tools.disambig.mle import MLEDisambiguator

# instantiate the Maximum Likelihood Disambiguator
mle = MLEDisambiguator.pretrained()

# The disambiguator expects pre-tokenized text
corpus["disambig"] = mle.disambiguate(corpus["Tokenized"])
# diacritized = [d.analyses[0].analysis['diac'] for d in disambig]

# %%
len(corpus["disambig"])
# Out:
# 112

# %%
from camel_tools.utils.normalize import normalize_alef_ar

for i in enumerate(corpus["disambig"]):
    corpus["disambig"][i[0]].dediaced = normalize_alef_ar(dediac_ar(corpus["disambig"][i[0]].analyses[0].analysis["lex"]))

# %%
corpus["disambig"][39].dediaced
# Out:
# 'ان'

# %% [markdown]
# ## 2.4 Deleting Stopwords
# ### 2.4.1 by Filtering

# %%
for i in enumerate(corpus["disambig"]):
    if corpus["disambig"][i[0]].analyses[0].analysis["pos"] in ("conj", "prep", "pron", "abbrev", "pron_dem", "conj_sub"):
        corpus["disambig"].pop(i[0])
        print(i)
# Out:
# (2, DisambiguatedWord(word='أن', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'أَنَّ', 'lex': 'أَنَّ', 'bw': 'أَنَّ/SUB_CONJ', 'gloss': 'that', 'pos': 'conj_sub', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'أَنَّ', 'caphi': '2_a_n_n_a', 'd1tok': 'أَنَّ', 'd2tok': 'أَنَّ', 'pos_logprob': -1.632802, 'd3tok': 'أَنَّ', 'd2seg': 'أَنَّ', 'pos_lex_logprob': -1.820082, 'num': 'na', 'ud': 'SCONJ', 'gen': 'na', 'catib6': 'PRT', 'root': '#.ن.ن', 'bwtok': 'أَنَّ', 'pattern': 'أَ2َّ', 'lex_logprob': -1.820082, 'atbtok': 'أَنَّ', 'atbseg': 'أَنَّ', 'd1seg': 'أَنَّ', 'stem': 'أَنَّ', 'stemgloss': 'that', 'stemcat': 'FW-Wa'})]))
# (4, DisambiguatedWord(word='أو', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'أَو', 'lex': 'أَو', 'bw': 'أَو/CONJ', 'gloss': 'or', 'pos': 'conj', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'أَوْ', 'caphi': '2_a_w', 'd1tok': 'أَوْ', 'd2tok': 'أَوْ', 'pos_logprob': -2.220282, 'd3tok': 'أَوْ', 'd2seg': 'أَوْ', 'pos_lex_logprob': -2.694687, 'num': 'na', 'ud': 'CCONJ', 'gen': 'na', 'catib6': 'PRT', 'root': '#.#.ن', 'bwtok': 'أَوْ', 'pattern': 'أَوْ', 'lex_logprob': -2.694687, 'atbtok': 'أَوْ', 'atbseg': 'أَوْ', 'd1seg': 'أَوْ', 'stem': 'أَو', 'stemgloss': 'or', 'stemcat': 'FW-Wa'})]))
# (11, DisambiguatedWord(word='في', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'فِي', 'lex': 'فِي', 'bw': 'فِي/PREP', 'gloss': 'in', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'فِي', 'caphi': 'f_i_y', 'd1tok': 'فِي', 'd2tok': 'فِي', 'pos_logprob': -1.002116, 'd3tok': 'فِي', 'd2seg': 'فِي', 'pos_lex_logprob': -1.411635, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'ف.#', 'bwtok': 'فِي', 'pattern': '1ِي', 'lex_logprob': -1.411635, 'atbtok': 'فِي', 'atbseg': 'فِي', 'd1seg': 'فِي', 'stem': 'فِي', 'stemgloss': 'in', 'stemcat': 'FW-Wa'})]))
# (16, DisambiguatedWord(word='وهم', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَهُم', 'lex': 'هُم', 'bw': 'وَ/CONJ+هُم/PRON_3MP', 'gloss': 'and+they_[masc.pl]', 'pos': 'pron', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': '0', 'per': '3', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'n', 'enc0': '0', 'rat': 'y', 'source': 'lex', 'form_gen': 'm', 'form_num': 'p', 'd3seg': 'وَ+_هُم', 'caphi': 'w_a_h_u_m', 'd1tok': 'وَ+_هُم', 'd2tok': 'وَ+_هُم', 'pos_logprob': -2.343646, 'd3tok': 'وَ+_هُم', 'd2seg': 'وَ+_هُم', 'pos_lex_logprob': -3.519737, 'num': 'p', 'ud': 'CCONJ+PRON', 'gen': 'm', 'catib6': 'PRT+NOM', 'root': 'ه', 'bwtok': 'وَ+_هُم', 'pattern': 'وَ1ُم', 'lex_logprob': -3.519737, 'atbtok': 'وَ+_هُم', 'atbseg': 'وَ+_هُم', 'd1seg': 'وَ+_هُم', 'stem': 'هُم', 'stemgloss': 'they_[masc.pl]', 'stemcat': 'FW-Wa'})]))
# (25, DisambiguatedWord(word='وعن', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَعَن', 'lex': 'عَن', 'bw': 'وَ/CONJ+عَن/PREP', 'gloss': 'and+from;about', 'pos': 'prep', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'وَ+_عَن', 'caphi': 'w_a_3_a_n', 'd1tok': 'وَ+_عَن', 'd2tok': 'وَ+_عَن', 'pos_logprob': -1.002116, 'd3tok': 'وَ+_عَن', 'd2seg': 'وَ+_عَن', 'pos_lex_logprob': -2.255199, 'num': 'na', 'ud': 'CCONJ+ADP', 'gen': 'na', 'catib6': 'PRT+PRT', 'root': 'ع.ن', 'bwtok': 'وَ+_عَن', 'pattern': 'وَ1َ2', 'lex_logprob': -2.255199, 'atbtok': 'وَ+_عَن', 'atbseg': 'وَ+_عَن', 'd1seg': 'وَ+_عَن', 'stem': 'عَن', 'stemgloss': 'from;about', 'stemcat': 'FW-Wa'})]))
# (34, DisambiguatedWord(word='لأن', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'لِأَنَّ', 'lex': 'أَنَّ', 'bw': 'لِأَنَّ/SUB_CONJ', 'gloss': 'because', 'pos': 'conj_sub', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'لِ+_أَنَّ', 'caphi': 'l_i_2_a_n_n_a', 'd1tok': 'لِأَنَّ', 'd2tok': 'لِ+_أَنَّ', 'pos_logprob': -1.632802, 'd3tok': 'لِ+_أَنَّ', 'd2seg': 'لِ+_أَنَّ', 'pos_lex_logprob': -1.820082, 'num': 'na', 'ud': 'ADP+SCONJ', 'gen': 'na', 'catib6': 'PRT+PRT', 'root': '#.ن.ن', 'bwtok': 'لِ+_أَنَّ', 'pattern': 'لِأَ2َّ', 'lex_logprob': -1.820082, 'atbtok': 'لِ+_أَنَّ', 'atbseg': 'لِ+_أَنَّ', 'd1seg': 'لِأَنَّ', 'stem': 'لِأَنَّ', 'stemgloss': 'because', 'stemcat': 'FW-Wa'})]))
# (36, DisambiguatedWord(word='منهما', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'مِنهُما', 'lex': 'مِن', 'bw': 'مِن/PREP+هُما/PRON_3D', 'gloss': 'from+them_(both)', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '3d_pron', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'مِن_+هُما', 'caphi': 'm_i_n_h_u_m_aa', 'd1tok': 'مِنهُما', 'd2tok': 'مِنهُما', 'pos_logprob': -1.002116, 'd3tok': 'مِن_+هُما', 'd2seg': 'مِنهُما', 'pos_lex_logprob': -1.691578, 'num': 'na', 'ud': 'ADP+PRON', 'gen': 'na', 'catib6': 'PRT+NOM', 'root': 'م.ن', 'bwtok': 'مِن_+هُما', 'pattern': '1ِ2هُما', 'lex_logprob': -1.691578, 'atbtok': 'مِن_+هُما', 'atbseg': 'مِن_+هُما', 'd1seg': 'مِنهُما', 'stem': 'مِن', 'stemgloss': 'from', 'stemcat': 'FW-Wa-n'})]))
# (39, DisambiguatedWord(word='في', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'فِي', 'lex': 'فِي', 'bw': 'فِي/PREP', 'gloss': 'in', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'فِي', 'caphi': 'f_i_y', 'd1tok': 'فِي', 'd2tok': 'فِي', 'pos_logprob': -1.002116, 'd3tok': 'فِي', 'd2seg': 'فِي', 'pos_lex_logprob': -1.411635, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'ف.#', 'bwtok': 'فِي', 'pattern': '1ِي', 'lex_logprob': -1.411635, 'atbtok': 'فِي', 'atbseg': 'فِي', 'd1seg': 'فِي', 'stem': 'فِي', 'stemgloss': 'in', 'stemcat': 'FW-Wa'})]))
# (45, DisambiguatedWord(word='من', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'مِن', 'lex': 'مِن', 'bw': 'مِن/PREP', 'gloss': 'from', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'مِن', 'caphi': 'm_i_n', 'd1tok': 'مِن', 'd2tok': 'مِن', 'pos_logprob': -1.002116, 'd3tok': 'مِن', 'd2seg': 'مِن', 'pos_lex_logprob': -1.691578, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'م.ن', 'bwtok': 'مِن', 'pattern': '1ِ2', 'lex_logprob': -1.691578, 'atbtok': 'مِن', 'atbseg': 'مِن', 'd1seg': 'مِن', 'stem': 'مِن', 'stemgloss': 'from', 'stemcat': 'FW-Wa'})]))
# (47, DisambiguatedWord(word='إذا', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'إِذا', 'lex': 'إِذا', 'bw': 'إِذا/CONJ', 'gloss': 'if;whether', 'pos': 'conj', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'إِذا', 'caphi': '2_i_dh_aa', 'd1tok': 'إِذا', 'd2tok': 'إِذا', 'pos_logprob': -1.632802, 'd3tok': 'إِذا', 'd2seg': 'إِذا', 'pos_lex_logprob': -3.071153, 'num': 'na', 'ud': 'SCONJ', 'gen': 'na', 'catib6': 'PRT', 'root': '#.ذ.#', 'bwtok': 'إِذا', 'pattern': 'إِ2ا', 'lex_logprob': -3.071153, 'atbtok': 'إِذا', 'atbseg': 'إِذا', 'd1seg': 'إِذا', 'stem': 'إِذا', 'stemgloss': 'if;whether', 'stemcat': 'FW-Wa'})]))
# (48, DisambiguatedWord(word='لأنه', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'لِأَنَّهُ', 'lex': 'أَنَّ', 'bw': 'لِأَنَّ/SUB_CONJ+هُ/PRON_3MS', 'gloss': 'because+it;he', 'pos': 'conj_sub', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '3ms_pron', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'لِ+_أَنَّ_+هُ', 'caphi': 'l_i_2_a_n_n_a_h_u', 'd1tok': 'لِأَنَّهُ', 'd2tok': 'لِ+_أَنَّهُ', 'pos_logprob': -1.632802, 'd3tok': 'لِ+_أَنَّ_+هُ', 'd2seg': 'لِ+_أَنَّهُ', 'pos_lex_logprob': -1.820082, 'num': 'na', 'ud': 'ADP+SCONJ+PRON', 'gen': 'na', 'catib6': 'PRT+PRT+NOM', 'root': '#.ن.ن', 'bwtok': 'لِ+_أَنَّ_+هُ', 'pattern': 'لِأَ2َّهُ', 'lex_logprob': -1.820082, 'atbtok': 'لِ+_أَنَّ_+هُ', 'atbseg': 'لِ+_أَنَّ_+هُ', 'd1seg': 'لِأَنَّهُ', 'stem': 'لِأَنَّ', 'stemgloss': 'because', 'stemcat': 'FW-Wa-n~a'})]))
# (50, DisambiguatedWord(word='إذا', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'إِذا', 'lex': 'إِذا', 'bw': 'إِذا/CONJ', 'gloss': 'if;whether', 'pos': 'conj', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'إِذا', 'caphi': '2_i_dh_aa', 'd1tok': 'إِذا', 'd2tok': 'إِذا', 'pos_logprob': -1.632802, 'd3tok': 'إِذا', 'd2seg': 'إِذا', 'pos_lex_logprob': -3.071153, 'num': 'na', 'ud': 'SCONJ', 'gen': 'na', 'catib6': 'PRT', 'root': '#.ذ.#', 'bwtok': 'إِذا', 'pattern': 'إِ2ا', 'lex_logprob': -3.071153, 'atbtok': 'إِذا', 'atbseg': 'إِذا', 'd1seg': 'إِذا', 'stem': 'إِذا', 'stemgloss': 'if;whether', 'stemcat': 'FW-Wa'})]))
# (51, DisambiguatedWord(word='كما', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'كَما', 'lex': 'كَما', 'bw': 'كَما/CONJ', 'gloss': 'and;as;also', 'pos': 'conj', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'كَما', 'caphi': 'k_a_m_aa', 'd1tok': 'كَما', 'd2tok': 'كَما', 'pos_logprob': -2.220282, 'd3tok': 'كَما', 'd2seg': 'كَما', 'pos_lex_logprob': -3.177835, 'num': 'na', 'ud': 'CCONJ', 'gen': 'na', 'catib6': 'PRT', 'root': 'ك', 'bwtok': 'كَما', 'pattern': '1َما', 'lex_logprob': -3.177835, 'atbtok': 'كَما', 'atbseg': 'كَما', 'd1seg': 'كَما', 'stem': 'كَما', 'stemgloss': 'and;as;also', 'stemcat': 'FW-Wa'})]))
# (53, DisambiguatedWord(word='لأنه', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'لِأَنَّهُ', 'lex': 'أَنَّ', 'bw': 'لِأَنَّ/SUB_CONJ+هُ/PRON_3MS', 'gloss': 'because+it;he', 'pos': 'conj_sub', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '3ms_pron', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'لِ+_أَنَّ_+هُ', 'caphi': 'l_i_2_a_n_n_a_h_u', 'd1tok': 'لِأَنَّهُ', 'd2tok': 'لِ+_أَنَّهُ', 'pos_logprob': -1.632802, 'd3tok': 'لِ+_أَنَّ_+هُ', 'd2seg': 'لِ+_أَنَّهُ', 'pos_lex_logprob': -1.820082, 'num': 'na', 'ud': 'ADP+SCONJ+PRON', 'gen': 'na', 'catib6': 'PRT+PRT+NOM', 'root': '#.ن.ن', 'bwtok': 'لِ+_أَنَّ_+هُ', 'pattern': 'لِأَ2َّهُ', 'lex_logprob': -1.820082, 'atbtok': 'لِ+_أَنَّ_+هُ', 'atbseg': 'لِ+_أَنَّ_+هُ', 'd1seg': 'لِأَنَّهُ', 'stem': 'لِأَنَّ', 'stemgloss': 'because', 'stemcat': 'FW-Wa-n~a'})]))
# (55, DisambiguatedWord(word='من', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'مِن', 'lex': 'مِن', 'bw': 'مِن/PREP', 'gloss': 'from', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'مِن', 'caphi': 'm_i_n', 'd1tok': 'مِن', 'd2tok': 'مِن', 'pos_logprob': -1.002116, 'd3tok': 'مِن', 'd2seg': 'مِن', 'pos_lex_logprob': -1.691578, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'م.ن', 'bwtok': 'مِن', 'pattern': '1ِ2', 'lex_logprob': -1.691578, 'atbtok': 'مِن', 'atbseg': 'مِن', 'd1seg': 'مِن', 'stem': 'مِن', 'stemgloss': 'from', 'stemcat': 'FW-Wa'})]))
# (62, DisambiguatedWord(word='في', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'فِي', 'lex': 'فِي', 'bw': 'فِي/PREP', 'gloss': 'in', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'فِي', 'caphi': 'f_i_y', 'd1tok': 'فِي', 'd2tok': 'فِي', 'pos_logprob': -1.002116, 'd3tok': 'فِي', 'd2seg': 'فِي', 'pos_lex_logprob': -1.411635, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'ف.#', 'bwtok': 'فِي', 'pattern': '1ِي', 'lex_logprob': -1.411635, 'atbtok': 'فِي', 'atbseg': 'فِي', 'd1seg': 'فِي', 'stem': 'فِي', 'stemgloss': 'in', 'stemcat': 'FW-Wa'})]))
# (69, DisambiguatedWord(word='بهن', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'بِهِنَّ', 'lex': 'بِ', 'bw': 'بِ/PREP+هِنَّ/PRON_3FP', 'gloss': 'with;by_+_them_[fem.pl.]', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '3fp_pron', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'بِ_+هِنَّ', 'caphi': 'b_i_h_i_n_n_a', 'd1tok': 'بِهِنَّ', 'd2tok': 'بِهِنَّ', 'pos_logprob': -1.002116, 'd3tok': 'بِ_+هُنَّ', 'd2seg': 'بِهِنَّ', 'pos_lex_logprob': -2.796325, 'num': 'na', 'ud': 'ADP+PRON', 'gen': 'na', 'catib6': 'PRT+NOM', 'root': 'ب', 'bwtok': 'بِ_+هِنَّ', 'pattern': '1ِهِنَّ', 'lex_logprob': -2.796325, 'atbtok': 'بِ_+هُنَّ', 'atbseg': 'بِ_+هِنَّ', 'd1seg': 'بِهِنَّ', 'stem': 'بِهِنَّ', 'stemgloss': 'with;by_+_them_[fem.pl.]', 'stemcat': 'FW-Wa'})]))
# (73, DisambiguatedWord(word='وهي', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَهِيَ', 'lex': 'هِيَ', 'bw': 'وَ/CONJ+هِيَ/PRON_3FS', 'gloss': 'and+it;they;she', 'pos': 'pron', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': '0', 'per': '3', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'n', 'enc0': '0', 'rat': 'y', 'source': 'lex', 'form_gen': 'f', 'form_num': 's', 'd3seg': 'وَ+_هِيَ', 'caphi': 'w_a_h_i_y_a', 'd1tok': 'وَ+_هِيَ', 'd2tok': 'وَ+_هِيَ', 'pos_logprob': -2.343646, 'd3tok': 'وَ+_هِيَ', 'd2seg': 'وَ+_هِيَ', 'pos_lex_logprob': -2.837664, 'num': 's', 'ud': 'CCONJ+PRON', 'gen': 'f', 'catib6': 'PRT+NOM', 'root': 'ه', 'bwtok': 'وَ+_هِيَ', 'pattern': 'وَ1ِيَ', 'lex_logprob': -2.837664, 'atbtok': 'وَ+_هِيَ', 'atbseg': 'وَ+_هِيَ', 'd1seg': 'وَ+_هِيَ', 'stem': 'هِيَ', 'stemgloss': 'it;they;she', 'stemcat': 'FW-Wa'})]))
# (75, DisambiguatedWord(word='وهي', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَهِيَ', 'lex': 'هِيَ', 'bw': 'وَ/CONJ+هِيَ/PRON_3FS', 'gloss': 'and+it;they;she', 'pos': 'pron', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': '0', 'per': '3', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'n', 'enc0': '0', 'rat': 'y', 'source': 'lex', 'form_gen': 'f', 'form_num': 's', 'd3seg': 'وَ+_هِيَ', 'caphi': 'w_a_h_i_y_a', 'd1tok': 'وَ+_هِيَ', 'd2tok': 'وَ+_هِيَ', 'pos_logprob': -2.343646, 'd3tok': 'وَ+_هِيَ', 'd2seg': 'وَ+_هِيَ', 'pos_lex_logprob': -2.837664, 'num': 's', 'ud': 'CCONJ+PRON', 'gen': 'f', 'catib6': 'PRT+NOM', 'root': 'ه', 'bwtok': 'وَ+_هِيَ', 'pattern': 'وَ1ِيَ', 'lex_logprob': -2.837664, 'atbtok': 'وَ+_هِيَ', 'atbseg': 'وَ+_هِيَ', 'd1seg': 'وَ+_هِيَ', 'stem': 'هِيَ', 'stemgloss': 'it;they;she', 'stemcat': 'FW-Wa'})]))
# (76, DisambiguatedWord(word='في', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'فِي', 'lex': 'فِي', 'bw': 'فِي/PREP', 'gloss': 'in', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'فِي', 'caphi': 'f_i_y', 'd1tok': 'فِي', 'd2tok': 'فِي', 'pos_logprob': -1.002116, 'd3tok': 'فِي', 'd2seg': 'فِي', 'pos_lex_logprob': -1.411635, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'ف.#', 'bwtok': 'فِي', 'pattern': '1ِي', 'lex_logprob': -1.411635, 'atbtok': 'فِي', 'atbseg': 'فِي', 'd1seg': 'فِي', 'stem': 'فِي', 'stemgloss': 'in', 'stemcat': 'FW-Wa'})]))
# (89, DisambiguatedWord(word='وهو', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَهُوَ', 'lex': 'هُوَ', 'bw': 'وَ/CONJ+هُوَ/PRON_3MS', 'gloss': 'and+it;he', 'pos': 'pron', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': '0', 'per': '3', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'n', 'enc0': '0', 'rat': 'y', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'وَ+_هُوَ', 'caphi': 'w_a_h_u_w_a', 'd1tok': 'وَ+_هُوَ', 'd2tok': 'وَ+_هُوَ', 'pos_logprob': -2.343646, 'd3tok': 'وَ+_هُوَ', 'd2seg': 'وَ+_هُوَ', 'pos_lex_logprob': -2.686641, 'num': 's', 'ud': 'CCONJ+PRON', 'gen': 'm', 'catib6': 'PRT+NOM', 'root': 'ه', 'bwtok': 'وَ+_هُوَ', 'pattern': 'وَ1ُوَ', 'lex_logprob': -2.686641, 'atbtok': 'وَ+_هُوَ', 'atbseg': 'وَ+_هُوَ', 'd1seg': 'وَ+_هُوَ', 'stem': 'هُوَ', 'stemgloss': 'it;he', 'stemcat': 'FW-Wa'})]))

# %% [markdown]
# ## 2.5 by using a stopwordlist

# %%
def stopwords(token_list, stopwords_list):
    poplist = []
    for i, token in enumerate(token_list):
        if token.dediaced not in stopwords_list:
            continue
        if token.dediaced in stopwords_list:
            token_list.pop(i)
            poplist.append(token)
    return poplist

# %%
## Stopwords provided by nltk
with open("./assets/stopwords_nltk.txt", "r", encoding="utf-8") as sf:
    stopwords_nltk = normalize_alef_ar(dediac_ar(sf.read()))

## Stopwords we chose to include
with open("./assets/stopwords_extra.txt", "r", encoding="utf-8") as sf:
    stopwords_extra = normalize_alef_ar(dediac_ar(sf.read()))

stpws = stopwords_nltk + " " + stopwords_extra

# %%
stopwords(corpus["disambig"], stpws)
# Out:
# [DisambiguatedWord(word='باللام', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'بِاللام', 'lex': 'لام', 'bw': 'بِ/PREP+ال/DET+لام/NOUN', 'gloss': 'with;by_+_the+lam_(Arabic_letter)', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': 'bi_prep', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'u', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'بِ+_ال+_لّام', 'caphi': 'b_i_l_l_aa_m', 'd1tok': 'بِاللّام', 'd2tok': 'بِ+_اللّام', 'pos_logprob': -0.4344233, 'd3tok': 'بِ+_ال+_لام', 'd2seg': 'بِ+_اللّام', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'ADP+NOUN', 'gen': 'm', 'catib6': 'PRT+NOM', 'root': 'NTWS', 'bwtok': 'بِ+_ال+_لام', 'pattern': 'بِالNTWS', 'lex_logprob': -99.0, 'atbtok': 'بِ+_اللّام', 'atbseg': 'بِ+_اللّام', 'd1seg': 'بِاللّام', 'stem': 'لام', 'stemgloss': 'lam_(Arabic_letter)', 'stemcat': 'NduAt_L'})]),
#  DisambiguatedWord(word='كقوله', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'كَقَوْله', 'lex': 'قَوْل', 'bw': 'كَ/PREP+قَوْل/NOUN+هُ/POSS_PRON_3MS', 'gloss': 'like;such_as+statement;remark+its;his', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': 'ka_prep', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'c', 'cas': 'u', 'enc0': '3ms_poss', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'كَ+_قَوْل_+هُ', 'caphi': 'k_a_q_a_w_l_h_u', 'd1tok': 'كَقَوْلهُ', 'd2tok': 'كَ+_قَوْلهُ', 'pos_logprob': -0.4344233, 'd3tok': 'كَ+_قَوْل_+هُ', 'd2seg': 'كَ+_قَوْلهُ', 'pos_lex_logprob': -3.478864, 'num': 's', 'ud': 'ADP+NOUN+PRON', 'gen': 'm', 'catib6': 'PRT+NOM+NOM', 'root': 'ق.#.ل', 'bwtok': 'كَ+_قَوْل_+هُ', 'pattern': 'كَ1َوْ3ه', 'lex_logprob': -3.478864, 'atbtok': 'كَ+_قَوْل_+هُ', 'atbseg': 'كَ+_قَوْل_+هُ', 'd1seg': 'كَقَوْلهُ', 'stem': 'قَوْل', 'stemgloss': 'statement;remark', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='قوله', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'قَوْلَهُ', 'lex': 'قَوْل', 'bw': 'قَوْل/NOUN+َ/CASE_DEF_ACC+هُ/POSS_PRON_3MS', 'gloss': 'statement;remark+its;his', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'c', 'cas': 'a', 'enc0': '3ms_poss', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'قَوْلَ_+هُ', 'caphi': 'q_a_w_l_a_h_u', 'd1tok': 'قَوْلَهُ', 'd2tok': 'قَوْلَهُ', 'pos_logprob': -0.4344233, 'd3tok': 'قَوْلَ_+هُ', 'd2seg': 'قَوْلَهُ', 'pos_lex_logprob': -3.478864, 'num': 's', 'ud': 'NOUN+PRON', 'gen': 'm', 'catib6': 'NOM+NOM', 'root': 'ق.#.ل', 'bwtok': 'قَوْل_+َ_+هُ', 'pattern': '1َوْ3َهُ', 'lex_logprob': -3.478864, 'atbtok': 'قَوْلَ_+هُ', 'atbseg': 'قَوْلَ_+هُ', 'd1seg': 'قَوْلَهُ', 'stem': 'قَوْل', 'stemgloss': 'statement;remark', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='كقوله', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'كَقَوْله', 'lex': 'قَوْل', 'bw': 'كَ/PREP+قَوْل/NOUN+هُ/POSS_PRON_3MS', 'gloss': 'like;such_as+statement;remark+its;his', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': 'ka_prep', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'c', 'cas': 'u', 'enc0': '3ms_poss', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'كَ+_قَوْل_+هُ', 'caphi': 'k_a_q_a_w_l_h_u', 'd1tok': 'كَقَوْلهُ', 'd2tok': 'كَ+_قَوْلهُ', 'pos_logprob': -0.4344233, 'd3tok': 'كَ+_قَوْل_+هُ', 'd2seg': 'كَ+_قَوْلهُ', 'pos_lex_logprob': -3.478864, 'num': 's', 'ud': 'ADP+NOUN+PRON', 'gen': 'm', 'catib6': 'PRT+NOM+NOM', 'root': 'ق.#.ل', 'bwtok': 'كَ+_قَوْل_+هُ', 'pattern': 'كَ1َوْ3ه', 'lex_logprob': -3.478864, 'atbtok': 'كَ+_قَوْل_+هُ', 'atbseg': 'كَ+_قَوْل_+هُ', 'd1seg': 'كَقَوْلهُ', 'stem': 'قَوْل', 'stemgloss': 'statement;remark', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='علي', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'عَلَى', 'lex': 'عَلَى', 'bw': 'عَلَى/PREP', 'gloss': 'on;above', 'pos': 'prep', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'spvar', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'عَلَى', 'caphi': '3_a_l_aa', 'd1tok': 'عَلَى', 'd2tok': 'عَلَى', 'pos_logprob': -1.002116, 'd3tok': 'عَلَى', 'd2seg': 'عَلَى', 'pos_lex_logprob': -1.819512, 'num': 'na', 'ud': 'ADP', 'gen': 'na', 'catib6': 'PRT', 'root': 'ع.ل.#', 'bwtok': 'عَلَى', 'pattern': '1َ2َى', 'lex_logprob': -1.819512, 'atbtok': 'عَلَى', 'atbseg': 'عَلَى', 'd1seg': 'عَلَى', 'stem': 'عَلَى', 'stemgloss': 'on;above', 'stemcat': 'FW-Wa'})]),
#  DisambiguatedWord(word='ما', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'ما', 'lex': 'ما', 'bw': 'ما/REL_PRON', 'gloss': 'what', 'pos': 'pron_rel', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'u', 'enc0': '0', 'rat': 'y', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ما', 'caphi': 'm_aa', 'd1tok': 'ما', 'd2tok': 'ما', 'pos_logprob': -1.808374, 'd3tok': 'ما', 'd2seg': 'ما', 'pos_lex_logprob': -2.456809, 'num': 's', 'ud': 'PRON', 'gen': 'm', 'catib6': 'NOM', 'root': 'م.#', 'bwtok': 'ما', 'pattern': '1ا', 'lex_logprob': -2.456809, 'atbtok': 'ما', 'atbseg': 'ما', 'd1seg': 'ما', 'stem': 'ما', 'stemgloss': 'what', 'stemcat': 'FW-Wa'})]),
#  DisambiguatedWord(word='واحدة', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'واحِدَةٍ', 'lex': 'واحِد', 'bw': 'واحِد/NOUN+َة/NSUFF_FEM_SG+ٍ/CASE_INDEF_GEN', 'gloss': 'one+[fem.sg.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'g', 'enc0': '0', 'rat': 'n', 'source': 'lex', 'form_gen': 'f', 'form_num': 's', 'd3seg': 'واحِدَةٍ', 'caphi': 'w_aa_7_i_d_a_t_i_n', 'd1tok': 'واحِدَةٍ', 'd2tok': 'واحِدَةٍ', 'pos_logprob': -2.147577, 'd3tok': 'واحِدَةٍ', 'd2seg': 'واحِدَةٍ', 'pos_lex_logprob': -3.191036, 'num': 's', 'ud': 'NUM', 'gen': 'f', 'catib6': 'NOM', 'root': '#.ح.د', 'bwtok': 'واحِد_+َة_+ٍ', 'pattern': 'وا2ِ3َةٍ', 'lex_logprob': -3.191036, 'atbtok': 'واحِدَةٍ', 'atbseg': 'واحِدَةٍ', 'd1seg': 'واحِدَةٍ', 'stem': 'واحِد', 'stemgloss': 'one', 'stemcat': 'N-ap'})]),
#  DisambiguatedWord(word='واحد', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'واحِدٍ', 'lex': 'واحِد', 'bw': 'واحِد/NOUN+ٍ/CASE_INDEF_GEN', 'gloss': 'one+[indef.gen.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'g', 'enc0': '0', 'rat': 'n', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'واحِدٍ', 'caphi': 'w_aa_7_i_d_i_n', 'd1tok': 'واحِدٍ', 'd2tok': 'واحِدٍ', 'pos_logprob': -2.147577, 'd3tok': 'واحِدٍ', 'd2seg': 'واحِدٍ', 'pos_lex_logprob': -3.191036, 'num': 's', 'ud': 'NUM', 'gen': 'm', 'catib6': 'NOM', 'root': '#.ح.د', 'bwtok': 'واحِد_+ٍ', 'pattern': 'وا2ِ3ٍ', 'lex_logprob': -3.191036, 'atbtok': 'واحِدٍ', 'atbseg': 'واحِدٍ', 'd1seg': 'واحِدٍ', 'stem': 'واحِد', 'stemgloss': 'one', 'stemcat': 'N-ap'})]),
#  DisambiguatedWord(word='وإنما', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَإِنَّما', 'lex': 'إِنَّما', 'bw': 'وَ/CONJ+إِنَّ/PSEUDO_VERB+ما/REL_PRON', 'gloss': 'and+but_rather;on_the_contrary', 'pos': 'verb_pseudo', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': 'mA_rel', 'rat': 'n', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'وَ+_إِنَّ_+ما', 'caphi': 'w_a_2_i_n_n_a_m_aa', 'd1tok': 'وَ+_إِنَّما', 'd2tok': 'وَ+_إِنَّما', 'pos_logprob': -2.387292, 'd3tok': 'وَ+_إِنَّ_+ما', 'd2seg': 'وَ+_إِنَّما', 'pos_lex_logprob': -2.713468, 'num': 'na', 'ud': 'CCONJ+CCONJ+PRON', 'gen': 'na', 'catib6': 'PRT+PRT+NOM', 'root': '#.ن.ن', 'bwtok': 'وَ+_إِنَّ_+ما', 'pattern': 'وَإِ2َّما', 'lex_logprob': -2.713468, 'atbtok': 'وَ+_إِنَّ_+ما', 'atbseg': 'وَ+_إِنَّ_+ما', 'd1seg': 'وَ+_إِنَّما', 'stem': 'إِنَّما', 'stemgloss': 'but_rather;on_the_contrary', 'stemcat': 'FW-Wa'})]),
#  DisambiguatedWord(word='عبد', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'عَبْد', 'lex': 'عَبْد', 'bw': 'عَبْد/NOUN_PROP', 'gloss': 'Abd', 'pos': 'noun_prop', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'u', 'enc0': '0', 'rat': 'r', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'عَبْد', 'caphi': '3_a_b_d', 'd1tok': 'عَبْد', 'd2tok': 'عَبْد', 'pos_logprob': -1.047404, 'd3tok': 'عَبْد', 'd2seg': 'عَبْد', 'pos_lex_logprob': -3.144074, 'num': 's', 'ud': 'PROPN', 'gen': 'm', 'catib6': 'PROP', 'root': 'ع.ب.د', 'bwtok': 'عَبْد', 'pattern': '1َ2ْ3', 'lex_logprob': -3.144074, 'atbtok': 'عَبْد', 'atbseg': 'عَبْد', 'd1seg': 'عَبْد', 'stem': 'عَبْد', 'stemgloss': 'Abd', 'stemcat': 'N0'})]),
#  DisambiguatedWord(word='قلب', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'قَلْبِ', 'lex': 'قَلْب', 'bw': 'قَلْب/NOUN+ِ/CASE_DEF_GEN', 'gloss': 'reversal;inversion+[def.gen.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'c', 'cas': 'g', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'قَلْبِ', 'caphi': 'q_a_l_b_i', 'd1tok': 'قَلْبِ', 'd2tok': 'قَلْبِ', 'pos_logprob': -0.4344233, 'd3tok': 'قَلْبِ', 'd2seg': 'قَلْبِ', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': 'ق.ل.ب', 'bwtok': 'قَلْب_+ِ', 'pattern': '1َ2ْ3ِ', 'lex_logprob': -99.0, 'atbtok': 'قَلْبِ', 'atbseg': 'قَلْبِ', 'd1seg': 'قَلْبِ', 'stem': 'قَلْب', 'stemgloss': 'reversal;inversion', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='صادا', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'صادا', 'lex': 'صاد', 'bw': 'صاد/PV+ا/PVSUFF_SUBJ:3MD', 'gloss': 'hunt;fish;trap+they_(both)_<verb>', 'pos': 'verb', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': '3', 'asp': 'p', 'vox': 'a', 'mod': 'i', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'n', 'source': 'lex', 'form_gen': 'm', 'form_num': 'd', 'd3seg': 'صادا', 'caphi': 's._aa_d_aa', 'd1tok': 'صادا', 'd2tok': 'صادا', 'pos_logprob': -1.023208, 'd3tok': 'صادا', 'd2seg': 'صادا', 'pos_lex_logprob': -99.0, 'num': 'd', 'ud': 'VERB', 'gen': 'm', 'catib6': 'VRB', 'root': 'ص.#.د', 'bwtok': 'صاد_+ا', 'pattern': '1ا3ا', 'lex_logprob': -99.0, 'atbtok': 'صادا', 'atbseg': 'صادا', 'd1seg': 'صادا', 'stem': 'صاد', 'stemgloss': 'hunt;fish;trap', 'stemcat': 'PV_V'})]),
#  DisambiguatedWord(word='الطاء', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الطاء', 'lex': 'طاء', 'bw': 'ال/DET+طاء/NOUN_PROP', 'gloss': "the+Ta'_(Arabic_letter)", 'pos': 'noun_prop', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'u', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_طّاء', 'caphi': '2_a_t._t._aa_2', 'd1tok': 'الطّاء', 'd2tok': 'الطّاء', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_طاء', 'd2seg': 'الطّاء', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': '#.#.#', 'bwtok': 'ال+_طاء', 'pattern': 'الطاء', 'lex_logprob': -99.0, 'atbtok': 'الطّاء', 'atbseg': 'الطّاء', 'd1seg': 'الطّاء', 'stem': 'طاء', 'stemgloss': "Ta'_(Arabic_letter)", 'stemcat': 'N0_Nh'})]),
#  DisambiguatedWord(word='وقد', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'وَقَد', 'lex': 'قَدْ', 'bw': 'وَ/CONJ+قَد/VERB_PART', 'gloss': 'and+(has;have)', 'pos': 'part_verb', 'prc3': '0', 'prc2': 'wa_conj', 'prc1': '0', 'prc0': 'na', 'per': 'na', 'asp': 'i', 'vox': 'na', 'mod': 'na', 'stt': 'na', 'cas': 'na', 'enc0': '0', 'rat': 'na', 'source': 'lex', 'form_gen': 'na', 'form_num': 'na', 'd3seg': 'وَ+_قَدْ', 'caphi': 'w_a_q_a_d', 'd1tok': 'وَ+_قَدْ', 'd2tok': 'وَ+_قَدْ', 'pos_logprob': -2.68122, 'd3tok': 'وَ+_قَدْ', 'd2seg': 'وَ+_قَدْ', 'pos_lex_logprob': -2.68122, 'num': 'na', 'ud': 'CCONJ+AUX', 'gen': 'na', 'catib6': 'PRT+PRT', 'root': 'ق.د', 'bwtok': 'وَ+_قَدْ', 'pattern': 'وَ1َ2ْ', 'lex_logprob': -2.68122, 'atbtok': 'وَ+_قَدْ', 'atbseg': 'وَ+_قَدْ', 'd1seg': 'وَ+_قَدْ', 'stem': 'قَد', 'stemgloss': '(has;have)', 'stemcat': 'FW-Wa'})]),
#  DisambiguatedWord(word='الصاد', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الصاد', 'lex': 'صاد', 'bw': 'ال/DET+صاد/NOUN_PROP', 'gloss': 'the+Sad_(Arabic_letter)', 'pos': 'noun_prop', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'u', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_صّاد', 'caphi': '2_a_s._s._aa_d', 'd1tok': 'الصّاد', 'd2tok': 'الصّاد', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_صاد', 'd2seg': 'الصّاد', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': '#.#.#', 'bwtok': 'ال+_صاد', 'pattern': 'الصاد', 'lex_logprob': -99.0, 'atbtok': 'الصّاد', 'atbseg': 'الصّاد', 'd1seg': 'الصّاد', 'stem': 'صاد', 'stemgloss': 'Sad_(Arabic_letter)', 'stemcat': 'NduAt'})]),
#  DisambiguatedWord(word='الزاي', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الزاي', 'lex': 'زاي', 'bw': 'ال/DET+زاي/NOUN', 'gloss': 'the+zay_(Arabic_letter.)', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'u', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_زّاي', 'caphi': '2_a_z_z_aa_y', 'd1tok': 'الزّاي', 'd2tok': 'الزّاي', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_زاي', 'd2seg': 'الزّاي', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': '#.#.#', 'bwtok': 'ال+_زاي', 'pattern': 'الزاي', 'lex_logprob': -99.0, 'atbtok': 'الزّاي', 'atbseg': 'الزّاي', 'd1seg': 'الزّاي', 'stem': 'زاي', 'stemgloss': 'zay_(Arabic_letter.)', 'stemcat': 'NduAt'})]),
#  DisambiguatedWord(word='جميعا', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'جَمِيعاً', 'lex': 'جَمِيع', 'bw': 'جَمِيع/NOUN+اً/CASE_INDEF_ACC', 'gloss': 'all_of;every_one_of+[acc.indef.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'i', 'cas': 'a', 'enc0': '0', 'rat': 'n', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'جَمِيعاً', 'caphi': 'j_a_m_ii_3_a_n', 'd1tok': 'جَمِيعاً', 'd2tok': 'جَمِيعاً', 'pos_logprob': -2.178485, 'd3tok': 'جَمِيعاً', 'd2seg': 'جَمِيعاً', 'pos_lex_logprob': -3.220138, 'num': 's', 'ud': 'NOUN', 'gen': 'f', 'catib6': 'NOM', 'root': 'ج.م.ع', 'bwtok': 'جَمِيع_+اً', 'pattern': '1َ2ِي3اً', 'lex_logprob': -3.220138, 'atbtok': 'جَمِيعاً', 'atbseg': 'جَمِيعاً', 'd1seg': 'جَمِيعاً', 'stem': 'جَمِيع', 'stemgloss': 'all_of;every_one_of', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='الصاد', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الصاد', 'lex': 'صاد', 'bw': 'ال/DET+صاد/NOUN_PROP', 'gloss': 'the+Sad_(Arabic_letter)', 'pos': 'noun_prop', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'u', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_صّاد', 'caphi': '2_a_s._s._aa_d', 'd1tok': 'الصّاد', 'd2tok': 'الصّاد', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_صاد', 'd2seg': 'الصّاد', 'pos_lex_logprob': -99.0, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': '#.#.#', 'bwtok': 'ال+_صاد', 'pattern': 'الصاد', 'lex_logprob': -99.0, 'atbtok': 'الصّاد', 'atbseg': 'الصّاد', 'd1seg': 'الصّاد', 'stem': 'صاد', 'stemgloss': 'Sad_(Arabic_letter)', 'stemcat': 'NduAt'})]),
#  DisambiguatedWord(word='الإمام', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الإِمامِ', 'lex': 'إِمام', 'bw': 'ال/DET+إِمام/NOUN+ِ/CASE_DEF_GEN', 'gloss': 'the+leader;imam+[def.gen.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'g', 'enc0': '0', 'rat': 'r', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_إِمامِ', 'caphi': '2_a_l_2_i_m_aa_m_i', 'd1tok': 'الإِمامِ', 'd2tok': 'الإِمامِ', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_إِمامِ', 'd2seg': 'الإِمامِ', 'pos_lex_logprob': -4.303641, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': '#.م.م', 'bwtok': 'ال+_إِمام_+ِ', 'pattern': 'الإِ2ا3ِ', 'lex_logprob': -4.303641, 'atbtok': 'الإِمامِ', 'atbseg': 'الإِمامِ', 'd1seg': 'الإِمامِ', 'stem': 'إِمام', 'stemgloss': 'leader;imam', 'stemcat': 'Ndu'})]),
#  DisambiguatedWord(word='نحو', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'نَحْوَ', 'lex': 'نَحْو', 'bw': 'نَحْو/NOUN+َ/CASE_DEF_ACC', 'gloss': 'manner;method+[def.acc.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': '0', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'c', 'cas': 'a', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'نَحْوَ', 'caphi': 'n_a_7_w_a', 'd1tok': 'نَحْوَ', 'd2tok': 'نَحْوَ', 'pos_logprob': -0.4344233, 'd3tok': 'نَحْوَ', 'd2seg': 'نَحْوَ', 'pos_lex_logprob': -4.133379, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': 'ن.ح.#', 'bwtok': 'نَحْو_+َ', 'pattern': '1َ2ْوَ', 'lex_logprob': -4.133379, 'atbtok': 'نَحْوَ', 'atbseg': 'نَحْوَ', 'd1seg': 'نَحْوَ', 'stem': 'نَحْو', 'stemgloss': 'manner;method', 'stemcat': 'N'})]),
#  DisambiguatedWord(word='الحق', analyses=[ScoredAnalysis(score=1.0, analysis={'diac': 'الحَقَّ', 'lex': 'حَقّ', 'bw': 'ال/DET+حَقّ/NOUN+َ/CASE_DEF_ACC', 'gloss': 'the+truth;right+[def.acc.]', 'pos': 'noun', 'prc3': '0', 'prc2': '0', 'prc1': '0', 'prc0': 'Al_det', 'per': 'na', 'asp': 'na', 'vox': 'na', 'mod': 'na', 'stt': 'd', 'cas': 'a', 'enc0': '0', 'rat': 'i', 'source': 'lex', 'form_gen': 'm', 'form_num': 's', 'd3seg': 'ال+_حَقَّ', 'caphi': '2_a_l_7_a_q_q_a', 'd1tok': 'الحَقَّ', 'd2tok': 'الحَقَّ', 'pos_logprob': -0.4344233, 'd3tok': 'ال+_حَقَّ', 'd2seg': 'الحَقَّ', 'pos_lex_logprob': -3.006976, 'num': 's', 'ud': 'NOUN', 'gen': 'm', 'catib6': 'NOM', 'root': 'ح.ق.ق', 'bwtok': 'ال+_حَقّ_+َ', 'pattern': 'ال1َ2َّ', 'lex_logprob': -2.992311, 'atbtok': 'الحَقَّ', 'atbseg': 'الحَقَّ', 'd1seg': 'الحَقَّ', 'stem': 'حَقّ', 'stemgloss': 'truth;right', 'stemcat': 'N'})])]

# %% [markdown]
# ## 3. Visualize
# ### 3.1 Visualize Arabic lex frequency

# %%
from collections import Counter

from wordcloud import WordCloud
import matplotlib.pyplot as plt          

# for Arabic text
from arabic_reshaper import reshape
from bidi.algorithm import get_display

rtl = lambda w: get_display(reshape(f'{w}'))

COUNTS = Counter([v.analyses[0].analysis["lex"] for v in corpus["disambig"]])
counts = {rtl(k):v for k, v in COUNTS.most_common(40)}

# Output to file
with open(f"./output/freqs_{TafsirId}_{Sura}_{Aya}.csv", 'w', encoding="utf-8") as f:
    for key in counts.keys():
        f.write("%s, %s\n" % (key, counts[key]))


# output to graphics and file
font_file = './assets/NotoNaskhArabic-Regular.ttf'
wordcloud = WordCloud(font_path=font_file, background_color="white").generate_from_frequencies(counts)
wordcloud.to_file(f"./output/{TafsirId}_{Sura}_{Aya}_wc_lex.png")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### 3.2 Visualize stemgloss frequency

# %%
from collections import Counter

from wordcloud import WordCloud          # pip install wordcloud
import matplotlib.pyplot as plt          

param = "stemgloss"

COUNTS = Counter([v.analyses[0].analysis[f"{param}"].split(";")[0] for v in corpus["disambig"]])
counts = {k:v for k, v in COUNTS.most_common(20)}

# Output to file
with open(f"./output/{TafsirId}_{Sura}_{Aya}_{param}_freqs.csv", 'w', encoding="utf-8") as f:
    for key in counts.keys():
        f.write("%s, %s\n" % (key, counts[key]))


# output to graphics and file
wordcloud = WordCloud(background_color="white").generate_from_frequencies(counts)
wordcloud.to_file(f"./output/{TafsirId}_{Sura}_{Aya}_{param}_wc.png")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
